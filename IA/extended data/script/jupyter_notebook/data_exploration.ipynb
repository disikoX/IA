# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sales = pd.read_excel("../../sales_data_extended.xlsx")
cust = pd.read_excel("../../customers_data_extended.xlsx")

print("Statistiques des ventes :")
print(sales.describe())

plt.figure(figsize=(10, 6))
sns.histplot(cust["Age"], bins=20, kde=True)
plt.title("Répartition par âge")
plt.savefig("M2/age_distribution.png")
# Out:
# Statistiques des ventes :
#            Sale_ID  Product_ID  Customer_ID                 Date    Quantity  \
# count   100.000000  100.000000   100.000000                  100  100.000000
# mean   1049.500000  102.720000  2026.210000  2023-04-09 20:24:00    1.900000
# min    1000.000000  101.000000  2001.000000  2023-01-01 00:00:00    1.000000
# 25%    1024.750000  101.750000  2013.750000  2023-02-25 00:00:00    1.000000
# 50%    1049.500000  102.000000  2027.500000  2023-04-18 12:00:00    2.000000
# 75%    1074.250000  104.000000  2039.000000  2023-06-04 00:00:00    3.000000
# max    1099.000000  105.000000  2049.000000  2023-06-28 00:00:00    3.000000
# std      29.011492    1.428993    14.217854                  NaN    0.797724
#
#        Sale_Price
# count   84.000000
# mean   116.779762
# min     22.500000
# 25%     50.000000
# 50%     75.000000
# 75%    150.000000
# max    360.000000
# std     92.240367
